# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("trainingdata02.csv")

# %%
data.head()
# Out:
#     battle_id  turn  total_turn    rank     weather              field  \
# 0  2099996083     0           5  1643.5         NaN  Psychic Terrain:5
# 1  2099996083     1           5  1643.5         NaN  Psychic Terrain:4
# 2  2099996083     2           5  1643.5  SunnyDay:5  Psychic Terrain:3
# 3  2099996083     3           5  1643.5  SunnyDay:4  Psychic Terrain:2
# 4  2099996083     4           5  1643.5  SunnyDay:3  Psychic Terrain:1
#
#       condition p1_side  p1a_form  p1a_hp  ... p2c_status p2c_tera p2d_form  \
# 0           NaN     NaN  Smeargle     100  ...        NaN  unknown  unknown
# 1  Trick Room:4     NaN  Smeargle       1  ...        NaN  unknown  unknown
# 2  Trick Room:3     NaN   Torkoal     100  ...        NaN  unknown  unknown
# 3  Trick Room:2     NaN   Torkoal     100  ...        fnt  unknown  unknown
# 4  Trick Room:1     NaN   Torkoal      55  ...        fnt  unknown  Urshifu
#
#   p2d_hp p2d_ability p2d_item                p2d_move p2d_status  p2d_tera win
# ...

# %%
data.size
# Out:
# 7401776

# %%
df = data.copy()

# %%
df1 = df[['p1a_form','p1b_form','p1c_form','p1d_form','p2a_form','p2b_form','p2c_form','p2d_form','win']]
df1
# Out:
#             p1a_form              p1b_form  p1c_form p1d_form  \
# 0           Smeargle           Calyrex-Ice   unknown  unknown
# 1           Smeargle           Calyrex-Ice   unknown  unknown
# 2            Torkoal           Calyrex-Ice  Smeargle  unknown
# 3            Torkoal           Calyrex-Ice  Smeargle  unknown
# 4            Torkoal           Calyrex-Ice  Smeargle  unknown
# ...              ...                   ...       ...      ...
# 100019  Flutter Mane                Chi-Yu   unknown  unknown
# 100020  Flutter Mane                Chi-Yu   unknown  unknown
# 100021       Groudon  Urshifu-Rapid-Strike   unknown  unknown
# 100022       Groudon  Urshifu-Rapid-Strike   unknown  unknown
# 100023       Ogerpon  Urshifu-Rapid-Strike   Groudon  unknown
#
#                    p2a_form     p2b_form    p2c_form p2d_form  win
# 0                Indeedee-F      Urshifu     unknown  unknown   -1
# 1                Indeedee-F      Urshifu     unknown  unknown   -1
# ...

# %%
df2 = pd.DataFrame(df1.p1a_form)
df2['names1_code'] = pd.factorize(df1['p1a_form'])[0]
df2
# Out:
#             p1a_form  names1_code
# 0           Smeargle            0
# 1           Smeargle            0
# 2            Torkoal            1
# 3            Torkoal            1
# 4            Torkoal            1
# ...              ...          ...
# 100019  Flutter Mane           26
# 100020  Flutter Mane           26
# 100021       Groudon           28
# 100022       Groudon           28
# 100023       Ogerpon           13
#
# [100024 rows x 2 columns]

# %%
## Here we creat a dic to store the pokemon name and the corresponding number of it 
name_to_code = dict(zip(df2['p1a_form'], df2['names1_code']))
name_to_code
# Out:
# {'Smeargle': 0,
#  'Torkoal': 1,
#  'Brute Bonnet': 2,
#  'Tornadus': 3,
#  'Tyranitar': 4,
#  'Iron Valiant': 5,
#  'Iron Jugulis': 6,
#  'Whimsicott': 7,
#  'Heatran': 8,
#  'Indeedee-F': 9,
#  'Lunala': 10,
#  'Urshifu-Rapid-Strike': 11,
#  'Calyrex-Ice': 12,
#  'Ogerpon': 13,
#  'Ogerpon-Teal-Tera': 14,
#  'Grimmsnarl': 15,
#  'Miraidon': 16,
#  'Urshifu': 17,
#  'Lycanroc': 18,
#  'Ogerpon-Wellspring': 19,
#  'Zacian-Crowned': 20,
#  'Calyrex-Shadow': 21,
#  'Goodra-Hisui': 22,
#  'Glimmora': 23,
#  'Tatsugiri-Stretchy': 24,
#  'Rillaboom': 25,
#  'Flutter Mane': 26,
#  'Incineroar': 27,
#  'Groudon': 28,
#  'Thundurus': 29,
#  'Jumpluff': 30,
#  'Chien-Pao': 31,
#  'Koraidon': 32,
#  'Entei': 33,
#  'Alcremie': 34,
#  'Maushold': 35,
#  'Kyogre': 36,
#  'Landorus': 37,
#  'Kingambit': 38,
#  'Scream Tail': 39,
#  'Annihilape': 40,
#  'Pelipper': 41,
#  'Weezing-Galar': 42,
#  'Stonjourner': 43,
#  'Frosmoth': 44,
#  'Amoonguss': 45,
#  'Mienshao': 46,
#  'Clefairy': 47,
# ...

# %%
## We find the p1_form
## first we map the name that existing in p1a
## we find the new names 
## we set the new names starting from maxi of existing name +1 
## the we creat a new dic to store the new name and nunber
## update the dict
df2['p1b_form'] = df1['p1b_form']
df2['names2_code'] = df2['p1b_form'].map(name_to_code)
new_names = df2['p1b_form'][df2['names2_code'].isnull()].unique()
start_code = len(name_to_code) + 1
new_name_to_code = dict(zip(new_names, range(start_code, start_code + len(new_names))))
name_to_code.update(new_name_to_code)
df2['names2_code'] = df2['names2_code'].fillna(df2['p1b_form'].map(new_name_to_code))
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
# [100024 rows x 4 columns]

# %%
df2['p1c_form'] = df1['p1c_form']
df2['names3_code'] = df2['p1c_form'].map(name_to_code)
new_names = df2['p1c_form'][df2['names3_code'].isnull()].unique()
start_code = len(name_to_code) + 1
new_name_to_code = dict(zip(new_names, range(start_code, start_code + len(new_names))))
name_to_code.update(new_name_to_code)
df2['names3_code'] = df2['names3_code'].fillna(df2['p1c_form'].map(new_name_to_code))
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code
# 0        unknown        483.0
# 1        unknown        483.0
# 2       Smeargle          0.0
# ...

# %%
df2['p1d_form'] = df1['p1d_form']
df2['names4_code'] = df2['p1d_form'].map(name_to_code)
new_names = df2['p1d_form'][df2['names4_code'].isnull()].unique()
start_code = len(name_to_code) + 1
new_name_to_code = dict(zip(new_names, range(start_code, start_code + len(new_names))))
name_to_code.update(new_name_to_code)
df2['names4_code'] = df2['names4_code'].fillna(df2['p1d_form'].map(new_name_to_code))
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code p1d_form  names4_code
# 0        unknown        483.0  unknown        483.0
# ...

# %%
df2['p2a_form'] = df1['p2a_form']
df2['names5_code'] = df2['p2a_form'].map(name_to_code)
new_names = df2['p2a_form'][df2['names5_code'].isnull()].unique()
start_code = len(name_to_code) + 1
new_name_to_code = dict(zip(new_names, range(start_code, start_code + len(new_names))))
name_to_code.update(new_name_to_code)
df2['names5_code'] = df2['names5_code'].fillna(df2['p2a_form'].map(new_name_to_code))
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code p1d_form  names4_code             p2a_form  \
# ...

# %%
new_name_to_code
# Out:
# {'Pichu': 485,
#  'Misdreavus': 486,
#  'Cacturne': 487,
#  'Pawmo': 488,
#  'Braviary': 489,
#  'Gurdurr': 490,
#  'Banette': 491,
#  'Thwackey': 492,
#  'Nosepass': 493,
#  'Samurott': 494,
#  'Vivillon-Icy Snow': 495,
#  'Gogoat': 496,
#  'Crocalor': 497,
#  'Glalie': 498,
#  'Squawkabilly': 499,
#  'Grumpig': 500,
#  'Dedenne': 501}

# %%
df2['p2b_form'] = df1['p2b_form']
df2['names6_code'] = df2['p2b_form'].map(name_to_code)
new_names = df2['p2b_form'][df2['names6_code'].isnull()].unique()
start_code = len(name_to_code) + 1
new_name_to_code = dict(zip(new_names, range(start_code, start_code + len(new_names))))
name_to_code.update(new_name_to_code)
df2['names6_code'] = df2['names6_code'].fillna(df2['p2b_form'].map(new_name_to_code))
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code p1d_form  names4_code             p2a_form  \
# ...

# %%
new_name_to_code
# Out:
# {'Whiscash': 502,
#  'Florges-Blue': 503,
#  'Vivillon-Marine': 504,
#  'Sawsbuck-Summer': 505,
#  'Appletun': 506,
#  'Eevee': 507,
#  'Vivillon-Pokeball': 508,
#  'Dodrio': 509,
#  'Vivillon-Monsoon': 510,
#  'Marshtomp': 511,
#  'Komala': 512,
#  'Sawsbuck': 513,
#  'Forretress': 514}

# %%
df2['p2c_form'] = df1['p2c_form']
df2['names7_code'] = df2['p2c_form'].map(name_to_code)
new_names = df2['p2c_form'][df2['names7_code'].isnull()].unique()
start_code = len(name_to_code) + 1
new_name_to_code = dict(zip(new_names, range(start_code, start_code + len(new_names))))
name_to_code.update(new_name_to_code)
df2['names7_code'] = df2['names7_code'].fillna(df2['p2c_form'].map(new_name_to_code))
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code p1d_form  names4_code             p2a_form  \
# ...

# %%
new_name_to_code
# Out:
# {}

# %%
df2['p2d_form'] = df1['p2d_form']
df2['names8_code'] = df2['p2d_form'].map(name_to_code)
new_names = df2['p2d_form'][df2['names8_code'].isnull()].unique()
start_code = len(name_to_code) + 1
new_name_to_code = dict(zip(new_names, range(start_code, start_code + len(new_names))))
name_to_code.update(new_name_to_code)
df2['names8_code'] = df2['names8_code'].fillna(df2['p2d_form'].map(new_name_to_code))
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code p1d_form  names4_code             p2a_form  \
# ...

# %%
new_name_to_code
# Out:
# {}

# %%
df2['win'] = df1['win']
df2
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code p1d_form  names4_code             p2a_form  \
# ...

# %%
## find the number of the name

name_to_find = 'unknown'
code_for_name = name_to_code.get(name_to_find, None)
print(f"The code corresponding to name {name_to_find} is: {code_for_name}")
# Out:
# The code corresponding to name unknown is: 483

# %%
## find the name of correspoding number

code_to_name = {v: k for k, v in name_to_code.items()}

# 查找数字“12”对应的名字
code_to_find = 12
name_for_code = code_to_name.get(code_to_find, None)
name_for_code
# Out:
# 'Calyrex-Ice'

# %% [markdown]
# # start model here

# %%
data = df2
data
# Out:
#             p1a_form  names1_code              p1b_form  names2_code  \
# 0           Smeargle            0           Calyrex-Ice         12.0
# 1           Smeargle            0           Calyrex-Ice         12.0
# 2            Torkoal            1           Calyrex-Ice         12.0
# 3            Torkoal            1           Calyrex-Ice         12.0
# 4            Torkoal            1           Calyrex-Ice         12.0
# ...              ...          ...                   ...          ...
# 100019  Flutter Mane           26                Chi-Yu         74.0
# 100020  Flutter Mane           26                Chi-Yu         74.0
# 100021       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100022       Groudon           28  Urshifu-Rapid-Strike         11.0
# 100023       Ogerpon           13  Urshifu-Rapid-Strike         11.0
#
#         p1c_form  names3_code p1d_form  names4_code             p2a_form  \
# ...

# %%
data = df2[['names1_code','names2_code','names3_code','names4_code','names5_code','names6_code','names7_code','names8_code','win']]
data
# Out:
#         names1_code  names2_code  names3_code  names4_code  names5_code  \
# 0                 0         12.0        483.0        483.0          9.0
# 1                 0         12.0        483.0        483.0          9.0
# 2                 1         12.0          0.0        483.0          9.0
# 3                 1         12.0          0.0        483.0          1.0
# 4                 1         12.0          0.0        483.0          1.0
# ...             ...          ...          ...          ...          ...
# 100019           26         74.0        483.0        483.0        145.0
# 100020           26         74.0        483.0        483.0        145.0
# 100021           28         11.0        483.0        483.0         32.0
# 100022           28         11.0        483.0        483.0         32.0
# 100023           13         11.0         28.0        483.0         32.0
#
#         names6_code  names7_code  names8_code  win
# 0              17.0          483          483   -1
# ...

# %%
X = df2[['names1_code','names2_code','names3_code','names4_code','names5_code','names6_code','names7_code','names8_code']]
Y = df2['win']

# %%
## For data handling
import pandas as pd
import numpy as np

## For plotting
import matplotlib.pyplot as plt
from seaborn import set_style

## This sets the plot style
## to have a grid on a white background
set_style("whitegrid")

# %%
## import model objects
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier
from sklearn.model_selection import train_test_split
from tree_helpers import SkNode, traversable_nodes
from sklearn.metrics import accuracy_score, classification_report

# %%
tree = DecisionTreeClassifier(
    #max_depth = 10, 
    min_samples_leaf = 5, # minimum number of samples in each leaf, to prevent overfitting
    random_state= 216)

rf = RandomForestClassifier(
    n_estimators = 500, # number of trees in ensemble
    #max_depth = 10, # max_depth of each tree
    min_samples_leaf = 5, 
    #max_features = 2, # default is round(sqrt(num_features)), which in this case is 1.
    bootstrap= True, # sampling with replacement
    #max_samples = 500, # number of training samples selected with replacement to build tree
    random_state = 216 # for consistency
    )

# Note:  by default all of the randomness is coming from using a random subset of features, not samples.  
# Since we have only 2 features the default settings are "worthless" for us: all 1000 trees would be identical, 
# and would only use one feature!

et = ExtraTreesClassifier(
    n_estimators = 500, 
    #max_depth = 10, 
    min_samples_leaf = 5, 
    #max_features = 2, 
    #bootstrap= True, 
    #max_samples = 500, 
    random_state = 216 
    )

# %%
X_train, X_test, y_train, y_test = train_test_split(X.copy(),Y.copy(),
                                                       shuffle=True,
                                                       random_state=153,
                                                       stratify=Y.copy(),
                                                       test_size=.2)

# %%
forest = RandomForestClassifier(n_estimators=500, max_depth=100,random_state=100)

forest.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, n_estimators=500, random_state=100)

# %%
forest.feature_importances_
score_df = pd.DataFrame({'feature':X_train.columns,
                            'importance_score': forest.feature_importances_})

score_df.sort_values('importance_score',ascending=False)
# Out:
#        feature  importance_score
# 1  names2_code          0.167992
# 5  names6_code          0.166448
# 4  names5_code          0.163259
# 0  names1_code          0.162478
# 6  names7_code          0.101158
# 2  names3_code          0.100063
# 7  names8_code          0.069343
# 3  names4_code          0.069258

# %%
y_pred = forest.predict(X_test)

# evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.7968507873031742
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.80      0.79      0.79      9844
#            0       0.86      1.00      0.92         6
#            1       0.80      0.81      0.80     10155
#
#     accuracy                           0.80     20005
#    macro avg       0.82      0.86      0.84     20005
# weighted avg       0.80      0.80      0.80     20005

# %%
et = ExtraTreesClassifier(n_estimators=500, max_depth=100)

et.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(max_depth=100, n_estimators=500)

# %%
et_score_df = pd.DataFrame({'feature':X_train.columns,
                            'importance_score': et.feature_importances_})

et_score_df.sort_values('importance_score',ascending=False)
# Out:
#        feature  importance_score
# 1  names2_code          0.166722
# 0  names1_code          0.165281
# 5  names6_code          0.165260
# 4  names5_code          0.165017
# 6  names7_code          0.098850
# 2  names3_code          0.098269
# 3  names4_code          0.070529
# 7  names8_code          0.070073

# %%
y_pred = et.predict(X_test)

# evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)
print(f'Accuracy: {accuracy}')
print(f'Classification Report:\n{report}')
# Out:
# Accuracy: 0.797500624843789
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.80      0.78      0.79      9844
#            0       1.00      1.00      1.00         6
#            1       0.79      0.81      0.80     10155
#
#     accuracy                           0.80     20005
#    macro avg       0.87      0.86      0.86     20005
# weighted avg       0.80      0.80      0.80     20005
